# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# ## Understanding the dataset for analyzing the data

# %% [markdown]
# W – Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work (also related: winning percentage)
#
# R – Runs scored: number of times a player crosses home plate
#
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
#
# H – Hit: reaching base because of a batted, fair ball without error by the defense
#
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
#
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
#
# HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
#
# BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# SO – Strikeout: number of batters who received strike three
#
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
#
# RA – Run average: number of runs allowed times nine divided by innings pitched
#
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls
#
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
#
# CG – Complete game: number of games where player was the only pitcher for their team
#
# SHO – Shutout: number of complete games pitched with no runs allowed
#
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
#
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result
#
# The dataset contains 16 features which contains the statistics summary of the baseball players and other one is our target variable. In this dataset 'W' is the target variable, which contains the number of predicted wins. Also we can see that the dataset contains only numerical values. and no categorical data. So by observing the dataset and problem statement it's a Regression type problem.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Checking the shape of the Dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# We can see that their are 30 Rows and 17 Columns in the Dataset including the Target Variable.

# %%
# Checking the Data type of the Dataset
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# We can see that Dataset contains mostly Integer data type. Only ERA contains float Data. And Also the Dataset contains only Numeric Datatype hence Encoding will not be required.

# %%
# Checking the Dataset for Null Values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# This information tells us that the Dataset has no Null Values and no Object datatype.

# %%
# Checking the unique values in the Dataset
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
# Checking and Reconfirming the Null Values.
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no Null Values in the Dataset.

# %%
# Lets Visualize the Null Values Dataset.
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null values in the Dataset.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the columns available in the Dataset.

# %%
# Checking the uniqueness of the target variable.
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# These are the unique values in the label.

# %%
# Checking the value count of the label.
df['W'].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %% [markdown]
# ## Statistical Description of the Dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This gives the statistical information of the dataset. The summary of this dataset looks perfect since there is no negative/ invalid values present.
#
# From the above description we can observe the following things.
#
# The counts of all the columns are same, this means there are no null values present in any of the columns.
#
# In the target column we can observe the mean is bit less than median(50%), so it is skewed to the left. Since the mean is 80.96 and maximum is 100, it means that the team won more matches.
#
# In the column R(Runs) also median is more than the mean then it is skewed to left. these differences can also be seen in the columns 2B, BB, SO, RA, ER, ERA and SHO. These columns are skewed to left.
#
# The mean is more than median in the columns AB, H, HR, SV and E which means they are skewed to right.
#
# Also the mean and the median are same in the columns 3B and SB which means the data is normal or symmetrical. Also the feature CG has mean bit higher than the meadian so its almost normal.
#
# There is a huge differences in max and 75% percentile(3rd quantile).
#
# So from these observations we can conclude that the outliers present in many of these columns. We will remove these outliers using some methods later.

# %%
# Visualizing the statistical description using Heatmap.
plt.figure(figsize=(16,8))
sns.heatmap(df.describe(),annot=True,fmt='.2f',linewidth=.2,linecolor='White')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %%
# Histogram for the target variable.
sns.histplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# From this Histogram plot, We can see that Data is normally distributed and their is no skewness present. The wins of the team is more in betwen 75 to 80 and its low in the range of 70 to 75. Minimum win is at 63 and maximum is at 100 and mean of the team win is at 80.

# %%
# checking how the data has been distributed in each column

plt.figure(figsize=(18,22),facecolor='White')
plotnumber=1
for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='red')
        plt.xlabel(column,fontsize=18)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From the distplot we can observe the following
#
# The target column 'W'(wins) looks normally distributed.
#
# The data in the feature 'R'(Runs) is not normal and the median is more than the mean so it is skewed to left.
#
# The data in the features 'H'(Hits), 'HR'(homeruns),'SV'(saves) and 'E'(errors) are not normal and skewed to right.
#
# '2B'(doubles) also looks normal and bit skewed.
#
# '3B'(tribles) and 'SB'(Stolen Bases) the data is normally distributed and there is no skewness.

# %%
# Checking for Outliers 
plt.figure(figsize=(16,20),facecolor='White')
plotnumber=1
for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column],color='green')
        plt.xlabel(column,fontsize=14)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We can see in the above Boxplot the columns 'R','ERA','SHO','SV' and 'E' contains Outliers. We will now remove these Outliers using Zscore Method.

# %% [markdown]
# ### Bivariate Analysis

# %%
# Checking the relations between runs and errors.
plt.figure(figsize=(8,6))
sns.scatterplot(df['R'],df['E'],hue=df['W'])
plt.title("Relation Between Run and Error")
plt.xlabel("Runs")
plt.ylabel("Error")
plt.show()

# %% [markdown]
# This scatter plot gives the relation between the Runs and the Errors on the basis of Wins. There is no linear relationship between these columns. We can infer that there is no correlation.

# %%
# Checking the Corelation between Runs and Hits
plt.figure(figsize=(8,6))
sns.scatterplot(df['R'],df['H'],hue=df['W'],palette='husl')
plt.title("Relation Between Runs and Hits")
plt.xlabel("Runs")
plt.ylabel("Hits")
plt.show()

# %% [markdown]
# There is no Linearity between the Columns.

# %%
# Checking relation Between AB and hits
plt.figure(figsize=(8,6))
sns.scatterplot(df['AB'],df['H'],hue=df['W'])
plt.title("Relation Between AB And Hits")
plt.xlabel('At-Bats')
plt.ylabel('Hits')
plt.show()

# %% [markdown]
# We can observe a slight colinearity between the features, as it shows that AB increases, hits also increases.

# %%
# Checking Relation Between ERA and RA.
plt.figure(figsize=(8,6))
sns.scatterplot(df['ERA'],df['RA'],hue=df['W'])
plt.title("Relation Between EarnedRunAverage and RunAverage")
plt.xlabel("Earned-Run-Average")
plt.ylabel("Run-Average")
plt.show()

# %% [markdown]
# We see a positive colinearity between both the features. As the Run Average increases, the Earned-Run-Average also increases. This indicates the winning data also increases

# %%
# Checking the Relation Between Runs and Wins.
plt.figure(figsize=(8,6))
sns.regplot(df['R'],df['W'],color='Green')
plt.title("Comparison Between Runs and Wins")
plt.xlabel("Runs")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# Here we can see a positive trend in the relation. It can be seen that as the run rate increases, the win rate also increases.

# %%
# Checking the comparison Between Wins and Walks.
plt.figure(figsize=(8,6))
sns.regplot(df['BB'],df['W'],color='Blue')
plt.title("Comparison Between Walks and Wins")
plt.xlabel("Walks")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# Here also the winning rate of the team increases as the number of Walks increases.

# %%
# Checking the Comparison Between Doubles and Wins
plt.figure(figsize=(8,6))
sns.regplot(df['2B'],df['W'],color='Orange')
plt.title("Comparison Between Doubles and Wins")
plt.xlabel("Doubles")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# The doubles also have good relationship with the target. When there is high number of doubles then there is high chances of winning.

# %%
# Checking relation between the stolen bases and Wins
plt.figure(figsize=(8,6))
sns.scatterplot(df['SB'],df['W'],color='red')
plt.title("Comparison Between Stolen Bases and Wins")
plt.xlabel("Stolen Bases")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# There is no linear relationship exists between these columns. The winning rate is high in the range 95-100 Stolen Bases.

# %%
# Checking the relation Between Wins and Runs Allowed.
plt.figure(figsize=(8,6))
sns.regplot(df['RA'],df['W'],color='Red')
plt.title("Comparison Run Allowed and Wins")
plt.xlabel("Runs Allowed")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# The target column has negative linear relationship with the feature Runs Allowed, since the data is falling from left to right which means label is highly correlated with the feature.

# %%
# Checking relation Between Earned Runs and Wins.
plt.figure(figsize=(8,6))
sns.regplot(df['ER'],df['W'],color='DarkGreen')
plt.title("Comparison Earned Runs and Wins")
plt.xlabel("Earned Runs")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# It can be observed that the data falling from left to right which means there is inverse linear relationship between the label and the target. As the ER decreases, the winning rate also decreases.

# %%
# Checking the relation between Earned Runs Average and Wins
plt.figure(figsize=(8,6))
plt.title('Comparision between Earned Runs Average and Wins')
sns.scatterplot(df['ERA'],df['W'])
plt.xlabel("Earned Runs Average")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# As the ERA decreases Wins rate also decreases, which means negative linear relatioship and target is highly correlated with the feature.

# %%
# Checking the relation between Earned Runs and Earned Runs Average
plt.figure(figsize=(8,6))
plt.title('Comparision between Earned Runs and Earned Runs Average')
sns.scatterplot(df['ER'],df['ERA'],hue=df["W"],palette="husl")
plt.xlabel("Earned Runs")
plt.ylabel("Earned Runs Average")
plt.show()

# %% [markdown]
# There is a strong linear relationship between the features. As the Earned Runs increases, Earned Runs Average also increases. The winning rate is high in the range 540-650

# %%
# Checking the relation between Saves and Wins
plt.figure(figsize=[8,6])
plt.title('Comparision between Saves and Wins')
sns.regplot(df['SV'],df['W'],color="darkOrange")
plt.xlabel("Saves")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# It can be observed that there is a positive linear relationship between the feature Saves and the label. As the Saves increases the wins of the team also increases.

# %%
# Checking the relation between ShutOuts and Wins
plt.figure(figsize=(8,6))
plt.title('Comparision between ShutOuts and Wins')
sns.regplot(df['SHO'],df['W'],color="blue")
plt.xlabel("ShutOuts")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# There is no much linearity between the feature and the label. In some of the data we can see whenever the shutouts is high then there is a chance of win.

# %%
# Checking the relation between Complete Games and Wins
plt.figure(figsize=(8,6))
plt.title('Comparision between Complete Games and Wins')
sns.regplot(df['CG'],df['W'],color="DarkGreen")
plt.xlabel("Complete Games")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# It can be observed that the data is scattered and has no much linear relationship between the feature and the label.

# %%
# Checking the relation between Triples and Wins
plt.figure(figsize=(8,6))
plt.title('Comparision between Triples and Wins')
sns.regplot(df['3B'],df['W'],color="orange")
plt.xlabel("Triples")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# There is a negative linear relationship between the feature 3B and the label Wins.

# %%
# Checking the relation between Error and Wins
plt.figure(figsize=(8,6))
plt.title('Comparision between Error and Wins')
sns.scatterplot(df['E'],df['W'],color="orange")
plt.xlabel("Error")
plt.ylabel("Wins")
plt.show()

# %% [markdown]
# The data is scattered and there is no linear raltionship between the two columns. As we can see the Error level is high in the range 86-95(say).

# %% [markdown]
# ## Multivariate Analysis

# %%
# Checking the pairwise relation in the Dataset.
sns.pairplot(df,hue='W',palette='husl')

# %% [markdown]
# This pair plot gives the pairwise relation between the columns which is plotted on the basis of target variable "W". Here we can observe the relation between the features and label.
#
# From this pairplot we can observe that the existence of correlation between two variables and on the diagonal we can see distribution plotting

# %% [markdown]
# ## Correlation Between the Target Variable and Independent Variable using Heatmap

# %%
corr = df.corr()
corr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# Visualizing the Correlation Matrix by plotting Heatmap.
plt.figure(figsize=(20,16))
sns.heatmap(corr,annot=True,linewidth=.2,linecolor="black",fmt='.2f',cmap='YlGnBu')
plt.yticks(rotation=0);

# %% [markdown]
# This heat map contains both positive and negative correlation.
#
# The target "W" is positively correlated with the features "SV", "SHO", "BB", "HR", "2B", "R" and "SO" . The target "W" is highly negatively correlated with the features "ERA","ER" and "RA". The label "W" is also negatively correlated with the features "E", "SB", "3B" and "AB". Apart from this label and feature relation we can also infer that the features "ERA", "ER" and "RA" are highly positively correlated with each other. Which causes multicollinearity problem, to avoid this problem will check VIF value and will drop the columns if necessary. The column "H" and "CG" has no correlation with the label, we can drop these columns.

# %% [markdown]
# ## Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(25,8))
corr['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title("Correlation Between Label And Features Using Bar Plot",fontsize=18)
plt.show()

# %% [markdown]
# Now we can easily analyse the data, here the feature "H" and "CG" has very less correaltion with the label. Let's drop them.

# %% [markdown]
# ## Data Cleaning

# %%
df.drop('H',axis=1,inplace=True)
df.drop('CG',axis=1,inplace=True)

# %%
df.head(5)
# Out:
#     W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 0  95  724  5575  300  42  139  383   973  104  641  601  3.73    8  56   88
# 1  83  696  5467  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2  81  669  5439  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3  76  622  5533  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4  74  689  5605  289  49  151  455  1259   83  803  746  4.64   12  35   86

# %% [markdown]
# ## Removing Outliers

# %% [markdown]
# ### Using ZScore Method

# %%
# Using Zscore method for removing the Outliers.
features = df[["R","ERA","SHO","SV","E"]]

# %%
from scipy.stats import zscore
z = np.abs(zscore(features))
z
# Out:
# array([[0.61907797, 0.50695519, 0.81462859, 1.67160651, 0.46146963],
#        [0.13443166, 0.25459752, 0.1728    , 0.24987932, 0.60719689],
#        [0.33290586, 0.64134684, 0.32091429, 0.65485616, 1.11724227],
#        [1.14641931, 0.05301004, 0.56777144, 0.78410408, 0.48575751],
#        [0.01327008, 1.53131824, 0.1728    , 1.04259994, 0.60719689],
#        [3.50964704, 0.35016492, 0.32091429, 1.17184786, 0.46146963],
#        [1.31142984, 0.16500309, 1.80205719, 0.6376231 , 0.0971515 ],
#        [0.4286812 , 0.20980031, 0.32091429, 0.00861653, 1.26296953],
#        [0.76562578, 0.48455658, 0.1728    , 2.18859821, 0.04857575],
#        [1.03448909, 0.79216414, 0.32091429, 0.39636031, 0.194303  ],
#        [1.08641548, 0.63537388, 0.56777144, 0.24987932, 1.79730279],
#        [0.70562195, 0.86533293, 0.41965715, 0.52560823, 0.68006051],
#        [0.47137623, 0.03658439, 0.1728    , 0.37912725, 0.0971515 ],
#        [0.55792022, 0.45618501, 0.1728    , 0.24987932, 0.02428788],
# ...

# %%
# Creating using New Dataframe
new_df = df[(z<3).all(axis=1)]
new_df
# Out:
#       W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 0    95  724  5575  300  42  139  383   973  104  641  601  3.73    8  56   88
# 1    83  696  5467  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2    81  669  5439  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3    76  622  5533  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4    74  689  5605  289  49  151  455  1259   83  803  746  4.64   12  35   86
# 6    87  764  5567  272  19  212  554  1227   63  698  652  4.03    4  48   93
# 7    81  713  5485  246  20  217  418  1331   44  693  646  4.05   10  43   77
# 8    80  644  5485  278  32  167  436  1310   87  642  604  3.74   12  60   95
# 9    78  748  5640  294  33  161  478  1148   71  753  694  4.31   10  40   97
# 10   88  751  5511  279  32  172  503  1233  101  733  680  4.24    9  45  119
# 11   86  729  5459  278  26  230  486  1392  121  618  572  3.57   13  39   85
# ...

# %%
df.shape
# Out:
# (30, 15)

# %%
new_df.shape
# Out:
# (29, 15)

# %% [markdown]
# There are 29 Rows and 15 Columns in our new dataFrame.

# %%
percent_loss = (30-29)/30*100

# %%
percent_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# #### As we can see their 3.33% Dataloss after removing Outliers.

# %% [markdown]
# ## Checking for Skewness

# %%
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# ### Removing Skewness using yeo-johnson method

# %%
Skewed_features = ['SHO','SV','E']

# %%
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
new_df[Skewed_features] = scaler.fit_transform(new_df[Skewed_features].values)
new_df[Skewed_features].head()
# Out:
#         SHO        SV         E
# 0 -0.787002  1.532753 -0.348265
# 1  0.236737  0.312020 -0.540820
# 2 -0.252844 -0.664137 -1.326125
# 3 -0.513555 -0.820689  0.650818
# 4  0.236737 -1.149165 -0.540820

# %%
# Checking Skewness after using transformation.
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# Now the Skewness has been removed

# %%
# After Removing Skewness lets check how the data has been distributed in each column.
features_skewed = ['SHO','SV','E']
plt.figure(figsize=(16,10),facecolor='white')
plotnumber=1
for column in new_df[features_skewed]:
    if plotnumber<=18:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(new_df[column],color='b')
        plt.xlabel(column,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Separating the independent and target variable into x and y

# %%
x = new_df.drop('W',axis=1)
y = new_df['W']

# %%
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %%
x.head()
# Out:
#      R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA       SHO  \
# 0  724  5575  300  42  139  383   973  104  641  601  3.73 -0.787002
# 1  696  5467  277  44  156  439  1264   70  700  653  4.07  0.236737
# 2  669  5439  303  29  141  533  1157   86  640  584  3.67 -0.252844
# 3  622  5533  260  27  136  404  1231   68  701  643  3.98 -0.513555
# 4  689  5605  289  49  151  455  1259   83  803  746  4.64  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %% [markdown]
# ### Standard Scalarization

# %%
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            R        AB        2B        3B        HR        BB        SO  \
# 0   0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 6   0.712585 -0.447345 -1.625627 -1.167936  1.915843 -0.885522  0.777970
# 7  -0.835605 -0.447345  0.260100  0.020490  0.196801 -0.550807  0.572335
# 8   1.497899  1.752672  1.202964  0.119526 -0.009484  0.230197 -1.013995
# 9   1.565212 -0.078310  0.319029  0.020490  0.368705  0.695081 -0.181661
# 10  1.071586 -0.816380  0.260100 -0.573723  2.362794  0.378960  1.375292
# 11 -0.454167 -1.412514 -1.802414 -1.068901  0.506228 -0.569402 -0.994411
# ...

# %% [markdown]
# Here the Data has been scaled now.

# %% [markdown]
# ## Checking VIF values to solve multicollinearity

# %%
# Finding the variation inflation factor in each scaled column i.e x.shaped[1] (1/(1-R2))
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#      VIF values Features
# 0      6.219825        R
# 1      9.828077       AB
# 2      2.683572       2B
# 3      3.196853       3B
# 4      7.369072       HR
# 5      2.686472       BB
# 6      2.741072       SO
# 7      1.757901       SB
# 8    179.096825       RA
# 9   1754.643859       ER
# 10  1310.260128      ERA
# 11     3.086344      SHO
# 12     4.021573       SV
# 13     1.742105        E

# %% [markdown]
# The VIF value is more than 10 in the columns "AB", "RA", "ER", "ERA". Let's drop these one by one. First drop the colummn having highest VIF value that is "ER".

# %%
x.drop('ER',axis=1,inplace=True)

# %%
# Againing checking the VIF after removing one column

vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values Features
# 0     4.352902        R
# 1     3.177214       AB
# 2     2.597985       2B
# 3     3.072775       3B
# 4     4.949255       HR
# 5     2.561982       BB
# 6     2.661842       SO
# 7     1.680467       SB
# 8   119.939744       RA
# 9   111.859162      ERA
# 10    2.932319      SHO
# 11    2.112465       SV
# 12    1.742101        E

# %% [markdown]
# Now we can see the multicollinearity still exists, so let me drop the column "RA".

# %%
x.drop("RA", axis=1, inplace=True)

# %%
# Againing checking the VIF after removing one column

vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values Features
# 0     4.250076        R
# 1     2.238746       AB
# 2     2.597917       2B
# 3     3.030073       3B
# 4     4.562014       HR
# 5     2.222720       BB
# 6     2.042786       SO
# 7     1.568151       SB
# 8     3.878177      ERA
# 9     2.651314      SHO
# 10    1.954370       SV
# 11    1.493128        E

# %% [markdown]
# It can be observed that all the values are less than 10 which means we have solved the multicollinearity problem. let's move to model building.

# %%
x.head()
# Out:
#           R        AB        2B        3B        HR        BB        SO  \
# 0  0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1  0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2 -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3 -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4  0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
#
#          SB       ERA       SHO        SV         E
# 0  0.905953 -0.511388 -0.787002  1.532753 -0.348265
# 1 -0.585315  0.238952  0.236737  0.312020 -0.540820
# 2  0.116458 -0.643801 -0.252844 -0.664137 -1.326125
# 3 -0.673037  0.040333 -0.513555 -0.820689  0.650818
# 4 -0.015124  1.496876  0.236737 -1.149165 -0.540820

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Finding Best Random State

# %%
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3,random_state=i)
    mod = LinearRegression()
    mod.fit(x_train,y_train)
    pred = mod.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 Score is:",maxAccu,'On Random State',maxRS)
# Out:
# Maximum r2 Score is: 0.9291790579976077 On Random State 50

# %% [markdown]
# We got the r2 Score as 92% on the random state 50.

# %% [markdown]
# ### Train Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3,random_state=maxRS)

# %% [markdown]
# ## Linear Regression

# %%
# Checking r2score for Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)

predLR=LR.predict(x_test)
print('The R2_score is:',r2_score(y_test,predLR))

print('The Mean Absolute Error is:',metrics.mean_absolute_error(y_test, predLR))
print('The Mean Squared Error is:',metrics.mean_squared_error(y_test, predLR))
print("The Root Mean Squared Error is:",np.sqrt(metrics.mean_squared_error(y_test, predLR)))
# Out:
# The R2_score is: 0.9291790579976077
# The Mean Absolute Error is: 2.4627865987898443
# The Mean Squared Error is: 10.163242343651952
# The Root Mean Squared Error is: 3.187984056367276

# %% [markdown]
# The R2 score value for Linear Regression model is 93%.

# %% [markdown]
# ## Linear Regression with Ridge

# %%
paramsRidge = {'alpha':[0.01, 0.1, 1.0,10.26], 'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
ridge=Ridge()
clf=GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'svd'}

# %%
# Checking R2 score for Ridge regressor
ridge=Ridge(alpha=10.26,solver='sag')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)

pred_ridge=ridge.predict(x_test)
print('The R2_Score is:',r2_score(y_test,pred_ridge))
print('The Mean Absolute Error is:',metrics.mean_absolute_error(y_test, pred_ridge))
print('The Mean Squared Error is:',metrics.mean_squared_error(y_test, pred_ridge))
print("The Root Mean Squared Error is:",np.sqrt(metrics.mean_squared_error(y_test, pred_ridge)))
# Out:
# The R2_Score is: 0.8228856629589623
# The Mean Absolute Error is: 4.385473723170479
# The Mean Squared Error is: 25.41700066376572
# The Root Mean Squared Error is: 5.041527612119736

# %% [markdown]
# Ridge gave a R2 score of 82%

# %% [markdown]
# ### Linear Regression with Lasso

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
lasso=Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)

pred_lasso=lasso.predict(x_test)
print('The R2_Score is:',r2_score(y_test,pred_lasso))

print('The Mean Absolute Error is:',metrics.mean_absolute_error(y_test, pred_lasso))
print('The Mean Squared Error is:',metrics.mean_squared_error(y_test, pred_lasso))
print("The Root Mean Squared Error is:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# The R2_Score is: 0.8642951302468397
# The Mean Absolute Error is: 3.8253497504300973
# The Mean Squared Error is: 19.4744864939597
# The Root Mean Squared Error is: 4.41299065192299

# %% [markdown]
# Got an R2 score of 86% for Lasso.

# %% [markdown]
# ## Random Forest Regressor

# %%
# Checking R2 score for  Random Forest Regressor
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)

pred_RFR=RFR.predict(x_test)
print('The R2_Score is:',r2_score(y_test,pred_RFR))

print("The Mean Absolute Error is:",metrics.mean_absolute_error(y_test, pred_RFR))
print('The Mean Squared Error is:',metrics.mean_squared_error(y_test, pred_RFR))
print("The Root Mean Squared Error is:",np.sqrt(metrics.mean_squared_error(y_test, pred_RFR)))
# Out:
# The R2_Score is: 0.6609339039917412
# The Mean Absolute Error is: 5.9433333333333325
# The Mean Squared Error is: 48.65807777777776
# The Root Mean Squared Error is: 6.975534228844252

# %% [markdown]
# We got an R2 Score of 66% for Random Forest Classifier

# %% [markdown]
# ## GradientBoosting Regressor

# %%
# Checking R2 score for  GradientBoosting Regressor
from sklearn.ensemble import GradientBoostingRegressor
GB=GradientBoostingRegressor()
GB.fit(x_train,y_train)

predGB=GB.predict(x_test)
print('The R2_Score is:',metrics.r2_score(y_test,predGB))

print('The Mean Absolute Error is:',metrics.mean_absolute_error(y_test, predGB))
print('The Mean Squared Error is:',metrics.mean_squared_error(y_test, predGB))
print("The Root Mean Squared Error is:",np.sqrt(metrics.mean_squared_error(y_test, predGB)))
# Out:
# The R2_Score is: 0.5269713166854105
# The Mean Absolute Error is: 6.148490509883899
# The Mean Squared Error is: 67.8825359857875
# The Root Mean Squared Error is: 8.239085870761846

# %% [markdown]
# We got R2 Score of 53% for Gradient Boosting Regressor.

# %% [markdown]
# ## Stochastic Gradient Descent Regressor

# %%
# Checking R2 score for Gradient Descent Regressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)

predSGD=SGD.predict(x_test)
print('The R2_Score is:',r2_score(y_test,predSGD))

print('The Mean Absolute Error is:',metrics.mean_absolute_error(y_test, predSGD))
print('The Mean Squared Error is:',metrics.mean_squared_error(y_test, predSGD))
print("The Root Mean Squared Error is:",np.sqrt(metrics.mean_squared_error(y_test, predSGD)))
# Out:
# The R2_Score is: 0.930875345883484
# The Mean Absolute Error is: 2.712616746814348
# The Mean Squared Error is: 9.919814561115826
# The Root Mean Squared Error is: 3.149573711014846

# %% [markdown]
# We got R2 Score of 93% for Stochastic Gradient Descent Regressor

# %% [markdown]
# ## Checking the cross validation score

# %%
# Checking cv score for Linear Regression
print("The Cross Validation Score for Linear Regression is:",cross_val_score(LR,x,y,cv=5).mean())
# Checking cv score for Ridge Regression
print("The Cross Validation Score for Ridge Regression is:",cross_val_score(ridge,x,y,cv=5).mean())
# Checking cv score for Lasso Regression
print("The Cross Validation Score for Lasso Regression is:",cross_val_score(lasso,x,y,cv=5).mean())
# Checking cv score for Random Forest Regressor
print("The Cross Validation Score for Random Forest Regressor is:",cross_val_score(RFR,x,y,cv=5).mean())
# Checking cv score for Gradient Boosting Regressor
print("The Cross Validation Score for Gradient Boosting Regressor is:",cross_val_score(GB,x,y,cv=5).mean())
# Checking cv score for Stochastic Gradient Descent Regressor
print("The Cross Validation Score for Stochastic Gradient Descent Regressor is:",cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# The Cross Validation Score for Linear Regression is: 0.37344412304899344
# The Cross Validation Score for Ridge Regression is: 0.349578664585831
# The Cross Validation Score for Lasso Regression is: 0.5206537019436117
# The Cross Validation Score for Random Forest Regressor is: -0.6917557611612417
# The Cross Validation Score for Gradient Boosting Regressor is: -1.1699759229961972
# The Cross Validation Score for Stochastic Gradient Descent Regressor is: 0.26690802754719833

# %% [markdown]
# #### From the difference of both R2 score and Cross Validation score we can conclude that Lasso Regressor as our best fitting model.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Lasso Regressor
parameters = {'alpha':[0.01, 0.1, 1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV=GridSearchCV(Lasso(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GCV.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': 'bool',
#  'max_iter': 2,
#  'selection': 'random',
#  'tol': 100}

# %%
# Creating final model
BaseBall = Lasso(alpha=1.0, fit_intercept="bool", max_iter=2, selection="random", tol=100)
BaseBall.fit(x_train, y_train)
pred = BaseBall.predict(x_test)

print('The R2_Score is:',r2_score(y_test,pred_lasso)*100)
print("The Root Mean Squared Error value is:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# The R2_Score is: 86.42951302468397
# The Root Mean Squared Error value is: 4.41299065192299

# %% [markdown]
# After tuning I am getting R2 score as 86.42% for our best model.

# %% [markdown]
# ### Saving the model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(BaseBall,"BaseBall_Case_Study.pkl")
# Out:
# ['BaseBall_Case_Study.pkl']

# %%
# Let's load the saved model and get the prediction

# Loading the saved model
model=joblib.load("BaseBall_Case_Study.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([68.08868348, 77.40131169, 77.04472259, 79.3629525 , 74.54843352,
#        74.44511188, 88.55421951, 89.53705579, 93.45066561])

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1          2          3          4          5  \
# Predicted  68.088683  77.401312  77.044723  79.362952  74.548434  74.445112
# Original   68.000000  78.000000  74.000000  88.000000  68.000000  64.000000
#
#                   6          7           8
# Predicted  88.55422  89.537056   93.450666
# Original   92.00000  90.000000  100.000000

# %% [markdown]
# ### Plotting Actual win vs Predicted win.

# %%
plt.figure(figsize=(8,8))
plt.scatter(y_test, prediction, c='r')
plt1 = max(max(prediction), max(y_test))
plt2 = min(min(prediction), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.xlabel('Actual Win', fontsize=15)
plt.ylabel('Predicted Win', fontsize=15)
plt.title("Lasso Regressor")
plt.show()
